# %%
def funcion(print, len, mensaje):
    

funcion()

# %%
import time

def temporizador(funcion):
    def wrapper(*args):
        inicio = time.time()
        programa = funcion(*args)
        fin = time.time()
        print(fin-inicio)
        return programa
    return wrapper

@temporizador
def funcionX(n):
    
    valor = n
    for i in range(n):
        valor = valor * valor
    
    
    return valor

print(funcionX(15))

# tiempoFuncionX = temporizador(funcionX)
# print(tiempoFuncionX(15))
# Out:
# 0.001962423324584961
# ...
# 0.001962423324584961
# ...
